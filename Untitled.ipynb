# %%
import yfinance as yf
import pandas as pd

# Download Reliance Industries (NSE) data
data = yf.download("RELIANCE.NS", start="2020-01-01", end="2024-12-31")

# Save to CSV
data.to_csv("reliance.csv")

# Preview
data.head()
# Out:
# /var/folders/gn/yy_br7zx0mzbg86m2vwjm9rc0000gn/T/ipykernel_56602/3611584131.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("RELIANCE.NS", start="2020-01-01", end="2024-12-31")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open      Volume
# Ticker     RELIANCE.NS RELIANCE.NS RELIANCE.NS RELIANCE.NS RELIANCE.NS
# Date
# 2020-01-01  678.021362  685.881324  676.179942  681.794149    14004468
# 2020-01-02  689.564270  692.101927  679.099312  679.099312    17710316
# 2020-01-03  690.395264  692.416395  684.039907  688.531297    20984698
# 2020-01-06  674.383362  686.240613  672.811358  682.692450    24519177
# 2020-01-07  684.758545  689.205022  679.773056  682.243314    16683622
